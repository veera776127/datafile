# %% [markdown]
# # DAV 5400 PROJECT

# %% [markdown]
# #### VEERAMANGALA TULASI RAM

# %% [markdown]
# # Part 1: Introduction

# %% [markdown]
# In this project, we'll be delving into a dataset that focuses on "Fruit Prices in 2020." This dataset provides valuable information about the prices of various fruits in the year 2020. It includes details about different types of fruits, their forms, retail prices, units of measurement for retail prices, yield, cup equivalent size, cup equivalent unit, and cup equivalent price.
#
# This dataset is a valuable resource for understanding the pricing dynamics of fruits in different forms and quantities. It can be instrumental for consumers, retailers, and policymakers in making informed decisions related to fruit consumption, procurement, and market analysis. By analyzing this dataset, we aim to gain insights into the pricing patterns of different fruits and their attributes.
#
# The project will be divided into the following key steps:
#
# Data Exploration: In this step, we will load the dataset and explore its contents to gain a preliminary understanding of the data.
#
# Exploratory Data Analysis (EDA): We will conduct exploratory data analysis to uncover patterns and relationships within the dataset, including summary statistics and visualizations.
#
# Inference: Based on our EDA, we will draw meaningful insights and conclusions about the fruit prices and attributes.
#
# Conclusion: We will summarize our findings and provide a clear conclusion based on the analysis.
#
# The dataset's comprehensive information about fruit prices in 2020 will help us make data-driven decisions and understand the factors that influence fruit pricing.

# %% [markdown]
# # Research Question:

# %% [markdown]
# How do the type of fruit, its form, and cup equivalent attributes interact in influencing fruit prices in 2020?
#
# Are there specific fruit types or forms that tend to have higher or lower prices, and what are the factors that contribute to these price variations?

# %% [markdown]
# These questions will  analysis in exploring the relationships between different attributes of fruits and their corresponding prices.

# %% [markdown]
# # Part 2:Data Summary:

# %% [markdown]
# The data for this analysis was obtained from the dataset titled 'Fruit Prices 2020,' which is publicly available on GitHub. The dataset provides information about the prices of various types of fruits in 2020.
#
# Number of Use Cases:
#
# There are a total of [insert number of rows] use cases (rows) in the dataset, each representing a specific fruit type and its attributes.
#
# Number of Attributes:
#
# The dataset consists of [insert number of columns] attributes (columns), each providing information about a particular aspect of the fruit, such as its type, form, retail price, retail price unit, yield, cup equivalent size, cup equivalent unit, and cup equivalent price.
#
# Data Types of Attributes:
#
# Here are the data types for each attribute in the dataset:
#
# Fruit: Categorical
#
# Form: Categorical
#
#
# RetailPrice: Numeric (Continuous)
#
# RetailPriceUnit: Categorical
#
# Yield: Numeric (Continuous)
#
# CupEquivalentSize: Numeric (Continuous)
#
# CupEquivalentUnit: Categorical
#
# CupEquivalentPrice: Numeric (Continuous)
#
# This information summarizes the dataset and provides an overview of its structure and data types.

# %% [markdown]
# # Code explanation:

# %% [markdown]
# This Python code utilizes the pandas library to perform a series of operations on a dataset stored in a CSV file. First, it loads the dataset from a specific URL and stores it as a pandas DataFrame named "data." It then calculates and displays two key statistics: the number of use cases, which corresponds to the rows in the dataset, and the number of attributes, equivalent to the dataset's columns. Furthermore, it extracts and lists the data types for each attribute (column) in the dataset. This code is a helpful starting point for understanding the dataset's size, structure, and the data types used in each column, all of which are fundamental aspects when working with data analysis and manipulation in Python.

# %%
# Define the URL of the dataset
url = 'https://raw.githubusercontent.com/veerAa776127/project1/main/Fruit%20Prices%202020.csv'

# %%
import pandas as pd
df = pd.read_csv(url)

# %%
df
# Out:
#                          Fruit    Form  RetailPrice RetailPriceUnit  Yield  \
# 0                       Apples   Fresh       1.5193       per pound   0.90
# 1           Apples, applesauce  Canned       1.0660       per pound   1.00
# 2       Apples, ready-to-drink   Juice       0.7804        per pint   1.00
# 3   Apples, frozen concentrate   Juice       0.5853        per pint   1.00
# 4                     Apricots   Fresh       2.9665       per pound   0.93
# ..                         ...     ...          ...             ...    ...
# 57                 Raspberries   Fresh       6.6391       per pound   0.96
# 58                 Raspberries  Frozen       4.1877       per pound   1.00
# 59                Strawberries   Fresh       2.5800       per pound   0.94
# 60                Strawberries  Frozen       2.8189       per pound   1.00
# 61                  Watermelon   Fresh       0.3604       per pound   0.52
#
#     CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# ...

# %%
import datasummary
v=datasummary.DataSummary(url)
print(v)
x=v.data_summary()
x
# Out:
# ...
# {'Use Cases': 62,
#  'Attributes': 8,
#  'Data Types for Attribute': {'Fruit': dtype('O'),
#   'Form': dtype('O'),
#   'RetailPrice': dtype('float64'),
#   'RetailPriceUnit': dtype('O'),
#   'Yield': dtype('float64'),
#   'CupEquivalentSize': dtype('float64'),
#   'CupEquivalentUnit': dtype('O'),
#   'CupEquivalentPrice': dtype('float64')}}

# %% [markdown]
# ## Part 3 Exploratory Data Analysis (EDA)

# %% [markdown]
# The provided code appears to be using a module or class named EDA for Exploratory Data Analysis. This code performs statistical analysis on a dataset and generates graphical analysis using both Matplotlib and Seaborn libraries. The code first computes and prints statistics for the dataset, and then it generates graphical visualizations.

# %%
import EDA

# %%
v=EDA.EDA().statistics()
print(v)
# Out:
#          Fruit   Form  RetailPrice RetailPriceUnit      Yield  \
# count       62     62    62.000000              62  62.000000
# unique      53      5          NaN               2        NaN
# top     Papaya  Fresh          NaN       per pound        NaN
# freq         2     24          NaN              51        NaN
# mean       NaN    NaN     2.616050             NaN   0.876129
# std        NaN    NaN     2.068129             NaN   0.174979
# min        NaN    NaN     0.360400             NaN   0.460000
# 25%        NaN    NaN     1.155850             NaN   0.722500
# 50%        NaN    NaN     1.868400             NaN   0.980000
# 75%        NaN    NaN     3.525600             NaN   1.000000
# max        NaN    NaN    10.552700             NaN   1.000000
#
#         CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# count           62.000000                62           62.000000
# unique                NaN                 2                 NaN
# ...

# %% [markdown]
# Statistics Summary:
# The statistics summary of the dataset provides insights into the numeric attributes. Here are the key takeaways from the output:
#
# Count: There are 62 entries in the dataset.
#
# Unique Values: For most columns, it indicates the number of unique values. For example, there are 53 unique fruit names, five unique forms, etc.
#
# Top Value: The most common value in each column is displayed (e.g., "Papaya" for "Fruit").
#
# Frequency: It shows the frequency of the most common value in each column.
#
# Mean: The average value for numeric columns (e.g., mean retail price).
#
# Standard Deviation: A measure of how spread out the values are.
#
# Min, 25%, 50% (Median), 75%, Max: These statistics provide insights into the distribution of the data, including the minimum, lower quartile, median, upper quartile, and maximum values for each numeric column.

# %%
v.head()
# Out:
#          Fruit   Form  RetailPrice RetailPriceUnit      Yield  \
# count       62     62     62.00000              62  62.000000
# unique      53      5          NaN               2        NaN
# top     Papaya  Fresh          NaN       per pound        NaN
# freq         2     24          NaN              51        NaN
# mean       NaN    NaN      2.61605             NaN   0.876129
#
#         CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# count           62.000000                62            62.00000
# unique                NaN                 2                 NaN
# top                   NaN            pounds                 NaN
# freq                  NaN                51                 NaN
# mean             1.704984               NaN             0.91974

# %%
# Accessing function through the class
price_attribute = EDA.EDA().graphical_analysis_matplotlib_price()

# %% [markdown]
# Graphical Analysis with Matplotlib:
# Following the statistical analysis, the code accesses the graphical_analysis_matplotlib_price method of the EDA class. This method appears to generate graphical visualizations using the Matplotlib library, specifically related to retail price for quantities

# %%
# Accessing function through the class`
price_attribute = EDA.EDA().graphical_analysis_seaborn_price()

# %% [markdown]
# Seaborn is a powerful data visualization library in Python that is often used to create informative and visually appealing plots. The graphical_analysis_seaborn_price() function is expected to generate Seaborn-based visualizations related to price attributes,

# %%
import analysis1

# %%
Method=analysis1.Inference(df)

# %%
i = analysis1.Inference(df)
# Call the analysis_seaborn method on the instance
result = i.analysis_seaborn()

# %%
# Call the analysis_seaborn method on the instance
result = i.analysis_matplotlib()

# %%
import Analysis2

# %%
Method=Analysis2.Inference(df)

# %%
result = Method.analysis_seaborn()

# %%
result = Method.analysis_matplotlib()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Conclusion
#
# In this project, we conducted an exploratory analysis of a dataset containing information about various fruits, their forms, retail prices, yields, and cup equivalent prices. The research question we aimed to answer was to understand how different factors, such as the form of the fruit, influenced retail prices and yield.
#
# Our analysis revealed several key findings:
#
# Price Variations by Fruit Form: We observed that the form of the fruit (e.g., fresh, canned, juice) significantly impacted retail prices. Fresh fruits tended to have higher prices per pound compared to canned or juice forms. This price variation is essential information for consumers looking for cost-effective options.
#
# Yield and Cup Equivalent Price: While the form of the fruit had a substantial influence on retail prices, it also influenced the yield and cup equivalent price. For example, canned fruits often had higher yields compared to fresh fruits, making them a more efficient choice for consumers in terms of the amount of fruit obtained per unit of weight. Cup equivalent prices provided a helpful comparison metric across different fruit forms.
#
# Insights for Consumers: The analysis provides valuable insights for consumers looking to make informed choices when purchasing fruits. Understanding the price differences and yield variations for different fruit forms can aid in budgeting and planning.
#
# Data Quality: It's worth noting that the dataset provided limited information. While it covered a variety of fruits, it did not include information about geographical or seasonal variations in prices, which could have added depth to the analysis.

# %% [markdown]
# # |References

# %% [markdown]
# https://data.cityofnewyork.us/City-Government/Youth-Engagement-By-Category/pqmq-sk82
#
# https://www.w3schools.com/python/numpy/numpy_random_binomial.asp
#
# https://www.jetbrains.com/pycharm/download/?section=windows
#
# https://www.tutorialspoint.com/statistics/analysis_of_variance.htm
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# https://seaborn.pydata.org/generated/seaborn.lineplot.html
